# %%
import os
import glob

import pandas as pd
import numpy as np

# %%
t = pd.read_csv("/cluster/home/sejinkim/projects/aaai21_survival_prediction/data/predictions/test_results_new.csv", index_col=1)
t
# Out:
#            Unnamed: 0.1  roc_auc_event  roc_auc_cancer  precision_event  \
# loss
# 0.000000           test       0.000000        0.000000         0.000000
# 1.524309  201030_063611       0.738544        0.746936         0.406822
# 1.870412  201030_063632       0.730473        0.749667         0.396456
# 1.519587  201030_063652       0.729943        0.740521         0.378301
# 1.638731  201030_063712       0.731189        0.745204         0.393617
# 1.690504  201030_063732       0.735347        0.752322         0.418350
# 1.669474  201030_063752       0.728284        0.746384         0.410332
# 1.536766  201030_064109       0.711502        0.734999         0.386986
# 1.611011  201030_064129       0.718041        0.733864         0.379019
# 1.674514  201030_064149       0.722612        0.739697         0.379975
# 1.770173  201030_064209       0.715893        0.732889         0.388255
# 1.701276  201030_064229       0.727323        0.738214         0.390621
# 1.655675  201030_064249       0.725174        0.741633         0.401957
#
#           precision_cancer  ci_event  ci_cancer
# loss
# 0.000000          0.000000  0.000000   0.000000
# 1.524309          0.324946  0.704625   0.758968
# 1.870412          0.307524  0.700374   0.757896
# 1.519587          0.294764  0.698994   0.751355
# 1.638731          0.312049  0.705612   0.753622
# 1.690504          0.339634  0.716077   0.756732
# 1.669474          0.327172  0.696358   0.752611
# 1.536766          0.299387  0.686666   0.741446
# 1.611011          0.287958  0.701585   0.741262
# 1.674514          0.285436  0.686700   0.744984
# 1.770173          0.292414  0.695606   0.740144
# 1.701276          0.290192  0.701529   0.746179
# 1.655675          0.316784  0.697895   0.749104

# %% [markdown]
# ## cnn

# %%
# 2, 0
with open("/cluster/projects/radiomics/Temp/sejin/slurm_logs/1556312-aaai_predict.out", 'r') as f:
    out2 = f.readlines()
    
with open("/cluster/projects/radiomics/Temp/sejin/slurm_logs/1556313-aaai_predict.out", 'r') as f:
    out2.extend(f.readlines())

# %%
results_idx = []
for n, line in enumerate(out2):
    if 'now testing' in line:
        results_idx.append(n)

results_timestamp_dict = {}
for i in results_idx:
    if "FAILED" not in out2[i+1]:
        model_name = out2[i].split("/")[0][-17:]
        timestamp  = out2[i+129].split("]")[-1]
        
        results_timestamp_dict[timestamp.strip()] = model_name
        print(model_name, timestamp)

# %%
def name(row):
    try:
        return results_timestamp_dict[row.name]
    except:
        return np.nan

# %%
results = pd.read_csv("/cluster/home/sejinkim/projects/aaai21_survival_prediction/data/predictions/test_results_new.csv", index_col=0)
results['model'] = results.apply(lambda x: name(x), axis=1)
results

# %% [markdown]
# ## deep mtlr

# %%
# 1, 1
with open("/cluster/projects/radiomics/Temp/sejin/slurm_logs/1555512-aaai_predict.out", 'r') as f:
    out2 = f.readlines()

# 1, 2
with open("/cluster/projects/radiomics/Temp/sejin/slurm_logs/1555510-aaai_predict.out", 'r') as f:
    out2.extend(f.readlines())
    
# 1, 0
with open("/cluster/projects/radiomics/Temp/sejin/slurm_logs/1555970-aaai_predict.out", 'r') as f:
    out2.extend(f.readlines())

# %%
results_idx = []
for n, line in enumerate(out2):
    if 'now testing' in line:
        results_idx.append(n)

results_timestamp_dict = {}
for i in results_idx:
    if "FAILED" not in out2[i+1]:
        model_name = out2[i].split("/")[0][-17:]
        timestamp  = out2[i+129].split("]")[-1]
        
        results_timestamp_dict[timestamp.strip()] = model_name
        print(model_name, timestamp)
# Out:
# dual_mtlr_1550692 201028_182226
#
# dual_mtlr_1550693 201028_182247
#
# dual_mtlr_1550694 201028_182307
#
# dual_mtlr_1550695 201028_182327
#
# dual_mtlr_1550696 201028_182348
#
# dual_mtlr_1550697 201028_182408
#
# dual_mtlr_1553700 201028_182428
#
# dual_mtlr_1553722 201028_182509
#
# dual_mtlr_1553724 201028_182530
#
# dual_mtlr_1553725 201028_182557
#
# dual_mtlr_1553726 201028_182618
#
# dual_mtlr_1553727 201028_182640
#
# dual_mtlr_1553553 201028_181806
#
# dual_mtlr_1553554 201028_181822
#
# dual_mtlr_1553555 201028_181837
#
# dual_mtlr_1553710 201028_181852
#
# dual_mtlr_1553711 201028_181907
#
# dual_mtlr_1553712 201028_181923
#
# dual_mtlr_1553713 201028_181938
#
# dual_mtlr_1553714 201028_181953
#
# dual_mtlr_1553715 201028_182008
#
# dual_mtlr_1553716 201028_182023
#
# dual_mtlr_1553718 201028_182039
#
# dual_mtlr_1553719 201028_182054
#
# dual_mtlr_1550685 201029_013846
#
# dual_mtlr_1550686 201029_013901
#
# dual_mtlr_1550687 201029_013916
#
# dual_mtlr_1550688 201029_013931
#
# dual_mtlr_1550689 201029_013946
#
# dual_mtlr_1550691 201029_014001

# %%
results_timestamp_dict
# Out:
# {'201028_182226': 'dual_mtlr_1550692',
#  '201028_182247': 'dual_mtlr_1550693',
#  '201028_182307': 'dual_mtlr_1550694',
#  '201028_182327': 'dual_mtlr_1550695',
#  '201028_182348': 'dual_mtlr_1550696',
#  '201028_182408': 'dual_mtlr_1550697',
#  '201028_182428': 'dual_mtlr_1553700',
#  '201028_182509': 'dual_mtlr_1553722',
#  '201028_182530': 'dual_mtlr_1553724',
#  '201028_182557': 'dual_mtlr_1553725',
#  '201028_182618': 'dual_mtlr_1553726',
#  '201028_182640': 'dual_mtlr_1553727',
#  '201028_181806': 'dual_mtlr_1553553',
#  '201028_181822': 'dual_mtlr_1553554',
#  '201028_181837': 'dual_mtlr_1553555',
#  '201028_181852': 'dual_mtlr_1553710',
#  '201028_181907': 'dual_mtlr_1553711',
#  '201028_181923': 'dual_mtlr_1553712',
#  '201028_181938': 'dual_mtlr_1553713',
#  '201028_181953': 'dual_mtlr_1553714',
#  '201028_182008': 'dual_mtlr_1553715',
#  '201028_182023': 'dual_mtlr_1553716',
#  '201028_182039': 'dual_mtlr_1553718',
#  '201028_182054': 'dual_mtlr_1553719',
#  '201029_013846': 'dual_mtlr_1550685',
#  '201029_013901': 'dual_mtlr_1550686',
#  '201029_013916': 'dual_mtlr_1550687',
#  '201029_013931': 'dual_mtlr_1550688',
#  '201029_013946': 'dual_mtlr_1550689',
#  '201029_014001': 'dual_mtlr_1550691'}

# %%
def name(row):
    try:
        return results_timestamp_dict[row.name]
    except:
        return np.nan

# %%
results = pd.read_csv("./data/predictions/test_results.csv", index_col=0)
results['model'] = results.apply(lambda x: name(x), axis=1)
results
# Out:
#                      loss  roc_auc_event  roc_auc_cancer  precision_event  \
# test             0.000000       0.000000        0.000000         0.000000
# 201028_181806    1.775341       0.769929        0.762716         0.470394
# 201028_181822    1.754020       0.770127        0.765341         0.467722
# 201028_181837    1.773527       0.775431        0.778186         0.470752
# 201028_181852    1.882492       0.766062        0.774222         0.419962
# 201028_181907    1.807350       0.771390        0.779465         0.444192
# 201028_181923    1.904580       0.754370        0.764343         0.429549
# 201028_181938    1.851185       0.776794        0.789987         0.454582
# 201028_181953    1.829707       0.772613        0.797053         0.456362
